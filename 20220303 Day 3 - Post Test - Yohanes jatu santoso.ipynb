# %%
#Latihan 1

# %%
print('Input bilangan:')
bil1 = int(input())
print ("\n")
print ("hasil looping 1 -",bil1)

for a in range (1,int(bil1)+1):
  print (a,end = "")
# Out:
# Input bilangan:
# 5
#
#
# hasil looping 1 - 5
# 12345

# %%
#Soal 1

# %%
print ("Print out integers which are multiples of 3 from 1 to 22")
for b in range (1,22+1):
  if(b%3==0):
      print (b,",",end = "")
# Out:
# Print out integers which are multiples of 3 from 1 to 22
# 3 ,6 ,9 ,12 ,15 ,18 ,21 ,

# %%
#Soal 2

# %%
print('Input bilangan:')
bil2 = int(input())
print ("\n")

def prime_check (bil2):
  result = False
  d = 0
  for c in range (1,bil2+1):
    if (bil2%c==0):
      d = d+1
    else:
      d = d
  if (d==2):
    print (bil2,"adalah bilangan prima")
  else:
    print (bil2,"bukan bilangan prima")

print(prime_check(bil2))
# Out:
# Input bilangan:
# 7
#
#
# 7 adalah bilangan prima
# None
